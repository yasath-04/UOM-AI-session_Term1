# %% [markdown]
# - Find a simple dataset from kaggle and build Linear Regression Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Linear Regression - Sheet1.csv')
df.head()
# Out:
#    X         Y
# 0  1  3.888889
# 1  2  4.555556
# 2  3  5.222222
# 3  4  5.888889
# 4  5  6.555556

# %%
plt.scatter(df['X'], df['Y'], color='blue', label='Data Points')

# %%
model = LinearRegression()
model.fit(df[['X']], df['Y'])
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(df[['X']])

# %%
plt.scatter(df['X'], df['Y'], color='blue', label='Data Points')
plt.plot(df[['X']], Y_pred, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

# %%
#predicting new values
new_X = np.array([[200]])
predicted_y = model.predict(new_X)
print(f'Predicted Y for X=200: {predicted_y[0]}')
# Out:
# Predicted Y for X=200: 133.89777758880717
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model.coef_, model.intercept_
# Out:
# (array([0.64004489]), np.float64(5.888799701613223))
