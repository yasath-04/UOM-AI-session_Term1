# %% [markdown]
# <a href="https://colab.research.google.com/github/yasath-04/UOM-AI-session_Term1/blob/main/yasa_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpts = np.array([2,4])
ypts = np.array([0,100])

plt.plot(xpts,ypts)
plt.show()
